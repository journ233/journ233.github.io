# %% [markdown]
# # Lecture 1030
#
# More pandas and charts with Altair using Berkeley 311 call data.

# %% [markdown]
# ## Import modules
# As usual, we'll import modules at the top of the notebook. This time, we don't need the `requests` module since we're not going to re-download the data from the Internet.

# %% [markdown]
# ### What is Altair?
#
# [Altair](https://altair-viz.github.io/) is a data visualization library for Python. `matplotlib` is usually the first data viz module Python programmers learn, but Altair is easier to use. The Altair community uses the alias `alt` when importing.

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# ## Import data
#
# We did a lot of work last week cleaning up the Berkeley 311 calls. We don't need to redo that work since we exported a clean version called `berkeley_311_clean.csv`.
#
# Remember that a `csv` file is just a plain-text file. That means that the file, just as it is, cannot retain the **dtype** of a column.
#
# So this time when we import the data, we'll want to make sure that we set up the dtypes we do know and parse `datetime` dtypes correctly.
#
# I also want to set **Case_ID** to an `object` dtype instead of an `int` dtype. Why would I want to do this? You can't operate on **Case_ID** like it's a number. You aren't going to add up the Case_IDs. So it's better to import that column as an `object`.
#
# Last thing: where you saved this notebook file matters. Where does the file `berkeley_311_clean.csv` exist locally on your computer?

# %%
berkeley_311 = pd.read_csv('../1023/berkeley_311_clean.csv', 
    dtype={
        'Case_ID': object,
    },
    parse_dates=['Date_Opened', 'Date_Closed', 'Close_Time']
)
# Out:
# /var/folders/gf/5t9yl_md2tqdlhjv6mqv1d440000gn/T/ipykernel_12325/3515394669.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   berkeley_311 = pd.read_csv('../1023/berkeley_311_clean.csv',

# %%
berkeley_311.head()
# Out:
#         Case_ID         Date_Opened Case_Status         Date_Closed  \
# 0  121000877593 2021-09-16 06:23:23      Closed 2021-09-20 11:22:22
# 1  121000876647 2021-09-13 10:50:00        Open                 NaT
# 2  121000809740 2020-11-06 16:51:00      Closed 2020-11-09 01:52:57
# 3  121000809739 2020-11-06 16:38:00      Closed 2020-11-09 01:41:12
# 4  121000793663 2020-09-01 11:32:00      Closed 2020-09-01 11:36:00
#
#                                Request_Category  \
# 0  Facilities, Electrical & Property Management
# 1                          Refuse and Recycling
# 2                 General Questions/information
# 3                 General Questions/information
# 4            Other Account Services and Billing
#
#               Request_SubCategory                 Request_Detail Object_Type  \
# 0  Parks/Marina Building Services                   Keys / Locks    Property
# 1                     Residential       Residential Bulky Pickup    Property
# 2                   Miscellaneous  Miscellaneous Service Request  Individual
# 3                   Miscellaneous  Miscellaneous Service Request    Property
# 4                          Marina    Payment Collection - Marina  Individual
#
#              APN                                     Street_Address      City  \
# 0            NaN  Intersection of Browning and Addison, BERKELEY...  Berkeley
# 1  054 180702800                                    1722 DWIGHT WAY  Berkeley
# 2            NaN                                                NaN  Berkeley
# 3  060 249305600                             1411 GRIZZLY PEAK BLVD  Berkeley
# 4            NaN                                                NaN  Berkeley
#
#   State Neighborhood   Latitude   Longitude                      Location  \
# 0    CA     Berkeley        NaN         NaN                           NaN
# 1    CA     Berkeley  37.862656 -122.275461  (37.86265624, -122.27546088)
# 2    CA     Berkeley        NaN         NaN                           NaN
# 3    CA     Berkeley  37.884799 -122.247874  (37.88479918, -122.24787412)
# 4    CA     Berkeley        NaN         NaN                           NaN
#
#         Close_Time
# 0  4 days 04:58:59
# 1              NaN
# 2  2 days 09:01:57
# 3  2 days 09:03:12
# 4  0 days 00:04:00

# %%
berkeley_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704673 entries, 0 to 704672
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Case_ID              704673 non-null  object
#  1   Date_Opened          704673 non-null  datetime64[ns]
#  2   Case_Status          704673 non-null  object
#  3   Date_Closed          667173 non-null  datetime64[ns]
#  4   Request_Category     704673 non-null  object
#  5   Request_SubCategory  704673 non-null  object
#  6   Request_Detail       704673 non-null  object
#  7   Object_Type          704673 non-null  object
#  8   APN                  413081 non-null  object
#  9   Street_Address       455047 non-null  object
#  10  City                 704673 non-null  object
#  11  State                704673 non-null  object
#  12  Neighborhood         704673 non-null  object
#  13  Latitude             407740 non-null  float64
#  14  Longitude            407740 non-null  float64
#  15  Location             407740 non-null  object
#  16  Close_Time           667173 non-null  object
# dtypes: datetime64[ns](2), float64(2), object(13)
# memory usage: 91.4+ MB

# %% [markdown]
# The **Close_Time** column didn't get typed as `timedelta`. It doesn't look like it's possible to do so with `pd.read_csv()`. (There's [an open issue](https://github.com/pandas-dev/pandas/issues/8185) on the pandas repo as of today's lecture.) So we'll just set it this way:

# %%
berkeley_311['Close_Time'] = pd.to_timedelta(berkeley_311['Close_Time'])

# %%
berkeley_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704673 entries, 0 to 704672
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Case_ID              704673 non-null  object
#  1   Date_Opened          704673 non-null  datetime64[ns]
#  2   Case_Status          704673 non-null  object
#  3   Date_Closed          667173 non-null  datetime64[ns]
#  4   Request_Category     704673 non-null  object
#  5   Request_SubCategory  704673 non-null  object
#  6   Request_Detail       704673 non-null  object
#  7   Object_Type          704673 non-null  object
#  8   APN                  413081 non-null  object
#  9   Street_Address       455047 non-null  object
#  10  City                 704673 non-null  object
#  11  State                704673 non-null  object
#  12  Neighborhood         704673 non-null  object
#  13  Latitude             407740 non-null  float64
#  14  Longitude            407740 non-null  float64
#  15  Location             407740 non-null  object
#  16  Close_Time           667173 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), float64(2), object(12), timedelta64[ns](1)
# memory usage: 91.4+ MB

# %%
berkeley_311
# Out:
#              Case_ID         Date_Opened Case_Status         Date_Closed  \
# 0       121000877593 2021-09-16 06:23:23      Closed 2021-09-20 11:22:22
# 1       121000876647 2021-09-13 10:50:00        Open                 NaT
# 2       121000809740 2020-11-06 16:51:00      Closed 2020-11-09 01:52:57
# 3       121000809739 2020-11-06 16:38:00      Closed 2020-11-09 01:41:12
# 4       121000793663 2020-09-01 11:32:00      Closed 2020-09-01 11:36:00
# ...              ...                 ...         ...                 ...
# 704668  121001011148 2023-06-12 13:06:00      Closed 2023-07-06 13:34:09
# 704669  121001014556 2023-06-29 14:01:00      Closed 2023-07-06 15:26:38
# 704670  121001005559 2023-05-17 11:56:00      Closed 2023-07-06 12:07:40
# 704671  121000883511 2021-10-13 10:59:00      Closed 2023-07-06 06:55:14
# 704672  121001013680 2023-06-26 12:42:00      Closed 2023-07-06 11:47:40
#
#                                     Request_Category  \
# 0       Facilities, Electrical & Property Management
# 1                               Refuse and Recycling
# 2                      General Questions/information
# 3                      General Questions/information
# 4                 Other Account Services and Billing
# ...                                              ...
# 704668                          Refuse and Recycling
# 704669                          Refuse and Recycling
# 704670                          Refuse and Recycling
# 704671                   Parks, Trees and Vegetation
# 704672                          Refuse and Recycling
#
#                    Request_SubCategory                  Request_Detail  \
# 0       Parks/Marina Building Services                    Keys / Locks
# 1                          Residential        Residential Bulky Pickup
# 2                        Miscellaneous   Miscellaneous Service Request
# 3                        Miscellaneous   Miscellaneous Service Request
# 4                               Marina     Payment Collection - Marina
# ...                                ...                             ...
# 704668                      Commercial      Commercial Site Inspection
# 704669                         Request                     Cart Repair
# 704670                     Residential     Residential Site Inspection
# 704671                           Trees                    Tree Pruning
# 704672                     Residential  Residential Cart Size Decrease
#
#        Object_Type            APN  \
# 0         Property            NaN
# 1         Property  054 180702800
# 2       Individual            NaN
# 3         Property  060 249305600
# 4       Individual            NaN
# ...            ...            ...
# 704668    Property  058 217100500
# 704669    Property  053 167101600
# 704670    Property  055 191404100
# 704671    Property  060 244500103
# 704672    Property  052 156509000
#
#                                            Street_Address      City State  \
# 0       Intersection of Browning and Addison, BERKELEY...  Berkeley    CA
# 1                                         1722 DWIGHT WAY  Berkeley    CA
# 2                                                     NaN  Berkeley    CA
# 3                                  1411 GRIZZLY PEAK BLVD  Berkeley    CA
# 4                                                     NaN  Berkeley    CA
# ...                                                   ...       ...   ...
# 704668                                      1924 CEDAR ST  Berkeley    CA
# 704669                                     1513 OREGON ST  Berkeley    CA
# 704670                                 2326 SPAULDING AVE  Berkeley    CA
# 704671                               1700 HOPKINS ST PARK  Berkeley    CA
# 704672                                   2946 MAGNOLIA ST  Berkeley    CA
#
#        Neighborhood   Latitude   Longitude                      Location  \
# 0          Berkeley        NaN         NaN                           NaN
# 1          Berkeley  37.862656 -122.275461  (37.86265624, -122.27546088)
# 2          Berkeley        NaN         NaN                           NaN
# 3          Berkeley  37.884799 -122.247874  (37.88479918, -122.24787412)
# 4          Berkeley        NaN         NaN                           NaN
# ...             ...        ...         ...                           ...
# 704668     Berkeley  37.877781 -122.272751  (37.87778105, -122.27275061)
# 704669     Berkeley  37.856370 -122.279024  (37.85636976, -122.27902376)
# 704670     Berkeley  37.864922 -122.280641  (37.86492171, -122.28064106)
# 704671     Berkeley  37.882542 -122.277477  (37.88254238, -122.27747688)
# 704672     Berkeley  37.857004 -122.249211   (37.8570041, -122.24921146)
#
#               Close_Time
# 0        4 days 04:58:59
# 1                    NaT
# 2        2 days 09:01:57
# 3        2 days 09:03:12
# 4        0 days 00:04:00
# ...                  ...
# 704668  24 days 00:28:09
# 704669   7 days 01:25:38
# 704670  50 days 00:11:40
# 704671 630 days 19:56:14
# 704672   9 days 23:05:40
#
# [704673 rows x 17 columns]

# %% [markdown]
# ## Explore data
#
# What do I do if I don't have a question yet? I'm not really sure what to look into with this 311 data. So I'm going to explore it a little bit. I might do some analysis, I might not.

# %% [markdown]
# ### Categories of incidents in 2022
#
# I'm curious about the different categories of incidents in the year 2022.
#
# First, I'll create a new dataframe `berkeley_311_2022` that subsets the `berkeley_311` data to just the cases that were open in 2022. (We discussed this last week, but subsetting data is a way to filter data.)

# %%
# asdf = berkeley_311.loc[
#     (berkeley_311['Date_Opened'] >= '2022-01-01') &
#     (berkeley_311['Date_Opened'] < '2023-01-01') 
#     # Why don't I use `berkeley_311['Date_Opened'] <= '2022-12-31']` ?
# ]

# %%
berkeley_311_2022 = berkeley_311.loc[
    (berkeley_311['Date_Opened'] >= '2022-01-01') &
    (berkeley_311['Date_Opened'] < '2023-01-01') 
    # Why don't I use `berkeley_311['Date_Opened'] <= '2022-12-31']` ?
].copy()

# %%
berkeley_311_2022
# Out:
#              Case_ID         Date_Opened Case_Status         Date_Closed  \
# 7       121000923118 2022-04-22 11:06:07      Closed 2022-04-23 01:57:00
# 8       121000923067 2022-04-22 08:35:00      Closed 2022-04-23 01:56:37
# 9       121000923227 2022-04-22 15:28:00      Closed 2022-04-23 01:57:41
# 10      121000923168 2022-04-22 13:21:00      Closed 2022-04-23 01:59:03
# 11      121000923276 2022-04-23 10:17:39      Closed 2022-04-23 05:07:20
# ...              ...                 ...         ...                 ...
# 703260  121000971323 2022-12-02 11:33:00      Closed 2023-06-29 13:53:39
# 703856  121000948662 2022-08-15 10:24:00      Closed 2023-06-30 14:55:20
# 703922  121000973880 2022-12-16 10:28:00      Closed 2023-06-30 09:45:00
# 704571  121000961524 2022-10-13 09:53:00      Closed 2023-07-06 15:14:28
# 704578  121000956737 2022-09-19 15:50:00      Closed 2023-07-06 14:13:27
#
#                               Request_Category Request_SubCategory  \
# 7       Streets, Utilities, and Transportation  Clean City Program
# 8       Streets, Utilities, and Transportation  Clean City Program
# 9       Streets, Utilities, and Transportation  Clean City Program
# 10      Streets, Utilities, and Transportation  Clean City Program
# 11                      Graffiti and Vandalism            Graffiti
# ...                                        ...                 ...
# 703260                    Refuse and Recycling             Request
# 703856                    Refuse and Recycling         Residential
# 703922           General Questions/information       Miscellaneous
# 704571                    Refuse and Recycling          Commercial
# 704578           General Questions/information       Miscellaneous
#
#                                Request_Detail Object_Type            APN  \
# 7             Illegal Dumping - City Property    Property            NaN
# 8             Illegal Dumping - City Property    Property  060 239107301
# 9             Illegal Dumping - City Property    Property  053 165200105
# 10            Illegal Dumping - City Property    Property  058 215601000
# 11      Graffiti Abatement - Internet Request  Individual            NaN
# ...                                       ...         ...            ...
# 703260                           Roll Off Bin    Property  057 201900103
# 703856        Residential Lost or Stolen Cart    Property  054 173700500
# 703922          Miscellaneous Service Request    Property  056 199705600
# 704571           Commercial Bin Size Increase    Property  054 170500801
# 704578          Miscellaneous Service Request    Property  057 205100400
#
#                                        Street_Address      City State  \
# 7       Intersection of Henry and Cedar, BERKELEY, CA  Berkeley    CA
# 8                                      1313 CURTIS ST  Berkeley    CA
# 9                                      1020 HEINZ AVE  Berkeley    CA
# 10                                   1635 VIRGINIA ST  Berkeley    CA
# 11                                                NaN  Berkeley    CA
# ...                                               ...       ...   ...
# 703260                                 2246 MILVIA ST  Berkeley    CA
# 703856                                   2741 DOHR ST  Berkeley    CA
# 703922                                    5 ACTON CIR  Berkeley    CA
# 704571                                2800 FOREST AVE  Berkeley    CA
# 704578                              1920 SHATTUCK AVE  Berkeley    CA
#
#        Neighborhood   Latitude   Longitude                      Location  \
# 7          Berkeley        NaN         NaN                           NaN
# 8          Berkeley  37.880943 -122.289982  (37.88094318, -122.28998212)
# 9          Berkeley  37.853063 -122.288187  (37.85306275, -122.28818668)
# 10         Berkeley  37.875586 -122.278920  (37.87558556, -122.27891974)
# 11         Berkeley        NaN         NaN                           NaN
# ...             ...        ...         ...                           ...
# 703260     Berkeley  37.867572 -122.271419   (37.8675722, -122.27141874)
# 703856     Berkeley  37.857214 -122.281251  (37.85721361, -122.28125113)
# 703922     Berkeley  37.868318 -122.283428  (37.86831774, -122.28342802)
# 704571     Berkeley  37.861189 -122.250483  (37.86118907, -122.25048336)
# 704578     Berkeley  37.873404 -122.268832  (37.87340377, -122.26883224)
#
#               Close_Time
# 7        0 days 14:50:53
# 8        0 days 17:21:37
# 9        0 days 10:29:41
# 10       0 days 12:38:03
# 11     -1 days +18:49:41
# ...                  ...
# 703260 209 days 02:20:39
# 703856 319 days 04:31:20
# 703922 195 days 23:17:00
# 704571 266 days 05:21:28
# 704578 289 days 22:23:27
#
# [58934 rows x 17 columns]

# %% [markdown]
# Let's look at that expression above.
# - I used `df.loc[ expression ]` because it is more performant than subsetting using just `df[ expression ]`. Either way is fine for your work. There are many ways to subset data in pandas; here's some more information about [those ways](https://pandas.pydata.org/docs/user_guide/indexing.html).
# - We're using `&` (instead of `and`). Remember our first lectures: `&` is a [bitwise operator](https://docs.python.org/3/reference/expressions.html#binary-bitwise-operations), while `and` is a [logical or boolean operator](https://docs.python.org/3/reference/expressions.html#boolean-operations).

# %%
berkeley_311_2022
# Out:
#              Case_ID         Date_Opened Case_Status         Date_Closed  \
# 7       121000923118 2022-04-22 11:06:07      Closed 2022-04-23 01:57:00
# 8       121000923067 2022-04-22 08:35:00      Closed 2022-04-23 01:56:37
# 9       121000923227 2022-04-22 15:28:00      Closed 2022-04-23 01:57:41
# 10      121000923168 2022-04-22 13:21:00      Closed 2022-04-23 01:59:03
# 11      121000923276 2022-04-23 10:17:39      Closed 2022-04-23 05:07:20
# ...              ...                 ...         ...                 ...
# 703260  121000971323 2022-12-02 11:33:00      Closed 2023-06-29 13:53:39
# 703856  121000948662 2022-08-15 10:24:00      Closed 2023-06-30 14:55:20
# 703922  121000973880 2022-12-16 10:28:00      Closed 2023-06-30 09:45:00
# 704571  121000961524 2022-10-13 09:53:00      Closed 2023-07-06 15:14:28
# 704578  121000956737 2022-09-19 15:50:00      Closed 2023-07-06 14:13:27
#
#                               Request_Category Request_SubCategory  \
# 7       Streets, Utilities, and Transportation  Clean City Program
# 8       Streets, Utilities, and Transportation  Clean City Program
# 9       Streets, Utilities, and Transportation  Clean City Program
# 10      Streets, Utilities, and Transportation  Clean City Program
# 11                      Graffiti and Vandalism            Graffiti
# ...                                        ...                 ...
# 703260                    Refuse and Recycling             Request
# 703856                    Refuse and Recycling         Residential
# 703922           General Questions/information       Miscellaneous
# 704571                    Refuse and Recycling          Commercial
# 704578           General Questions/information       Miscellaneous
#
#                                Request_Detail Object_Type            APN  \
# 7             Illegal Dumping - City Property    Property            NaN
# 8             Illegal Dumping - City Property    Property  060 239107301
# 9             Illegal Dumping - City Property    Property  053 165200105
# 10            Illegal Dumping - City Property    Property  058 215601000
# 11      Graffiti Abatement - Internet Request  Individual            NaN
# ...                                       ...         ...            ...
# 703260                           Roll Off Bin    Property  057 201900103
# 703856        Residential Lost or Stolen Cart    Property  054 173700500
# 703922          Miscellaneous Service Request    Property  056 199705600
# 704571           Commercial Bin Size Increase    Property  054 170500801
# 704578          Miscellaneous Service Request    Property  057 205100400
#
#                                        Street_Address      City State  \
# 7       Intersection of Henry and Cedar, BERKELEY, CA  Berkeley    CA
# 8                                      1313 CURTIS ST  Berkeley    CA
# 9                                      1020 HEINZ AVE  Berkeley    CA
# 10                                   1635 VIRGINIA ST  Berkeley    CA
# 11                                                NaN  Berkeley    CA
# ...                                               ...       ...   ...
# 703260                                 2246 MILVIA ST  Berkeley    CA
# 703856                                   2741 DOHR ST  Berkeley    CA
# 703922                                    5 ACTON CIR  Berkeley    CA
# 704571                                2800 FOREST AVE  Berkeley    CA
# 704578                              1920 SHATTUCK AVE  Berkeley    CA
#
#        Neighborhood   Latitude   Longitude                      Location  \
# 7          Berkeley        NaN         NaN                           NaN
# 8          Berkeley  37.880943 -122.289982  (37.88094318, -122.28998212)
# 9          Berkeley  37.853063 -122.288187  (37.85306275, -122.28818668)
# 10         Berkeley  37.875586 -122.278920  (37.87558556, -122.27891974)
# 11         Berkeley        NaN         NaN                           NaN
# ...             ...        ...         ...                           ...
# 703260     Berkeley  37.867572 -122.271419   (37.8675722, -122.27141874)
# 703856     Berkeley  37.857214 -122.281251  (37.85721361, -122.28125113)
# 703922     Berkeley  37.868318 -122.283428  (37.86831774, -122.28342802)
# 704571     Berkeley  37.861189 -122.250483  (37.86118907, -122.25048336)
# 704578     Berkeley  37.873404 -122.268832  (37.87340377, -122.26883224)
#
#               Close_Time
# 7        0 days 14:50:53
# 8        0 days 17:21:37
# 9        0 days 10:29:41
# 10       0 days 12:38:03
# 11     -1 days +18:49:41
# ...                  ...
# 703260 209 days 02:20:39
# 703856 319 days 04:31:20
# 703922 195 days 23:17:00
# 704571 266 days 05:21:28
# 704578 289 days 22:23:27
#
# [58934 rows x 17 columns]

# %% [markdown]
# One thing I'm seeing immediately is that the index of this new dataframe `berkeley_311_2022` looks kind of weird. It's no longer sequential. I can reset the index to make it sequential by using `df.reset_index(drop=True)`.
#
# ```python
# berkeley_311_2022 = berkeley_311_2022.reset_index(drop=True)
# ```
#
# Alternatively, instead of copying the original dataframe with df.copy(), we can reset the index at the same time we subset the data:

# %%
berkeley_311_2022 = berkeley_311.loc[
    (berkeley_311['Date_Opened'] >= '2022-01-01') &
    (berkeley_311['Date_Opened'] < '2023-01-01') 
].reset_index(drop=True)

# %%
berkeley_311_2022
# Out:
#             Case_ID         Date_Opened Case_Status         Date_Closed  \
# 0      121000923118 2022-04-22 11:06:07      Closed 2022-04-23 01:57:00
# 1      121000923067 2022-04-22 08:35:00      Closed 2022-04-23 01:56:37
# 2      121000923227 2022-04-22 15:28:00      Closed 2022-04-23 01:57:41
# 3      121000923168 2022-04-22 13:21:00      Closed 2022-04-23 01:59:03
# 4      121000923276 2022-04-23 10:17:39      Closed 2022-04-23 05:07:20
# ...             ...                 ...         ...                 ...
# 58929  121000971323 2022-12-02 11:33:00      Closed 2023-06-29 13:53:39
# 58930  121000948662 2022-08-15 10:24:00      Closed 2023-06-30 14:55:20
# 58931  121000973880 2022-12-16 10:28:00      Closed 2023-06-30 09:45:00
# 58932  121000961524 2022-10-13 09:53:00      Closed 2023-07-06 15:14:28
# 58933  121000956737 2022-09-19 15:50:00      Closed 2023-07-06 14:13:27
#
#                              Request_Category Request_SubCategory  \
# 0      Streets, Utilities, and Transportation  Clean City Program
# 1      Streets, Utilities, and Transportation  Clean City Program
# 2      Streets, Utilities, and Transportation  Clean City Program
# 3      Streets, Utilities, and Transportation  Clean City Program
# 4                      Graffiti and Vandalism            Graffiti
# ...                                       ...                 ...
# 58929                    Refuse and Recycling             Request
# 58930                    Refuse and Recycling         Residential
# 58931           General Questions/information       Miscellaneous
# 58932                    Refuse and Recycling          Commercial
# 58933           General Questions/information       Miscellaneous
#
#                               Request_Detail Object_Type            APN  \
# 0            Illegal Dumping - City Property    Property            NaN
# 1            Illegal Dumping - City Property    Property  060 239107301
# 2            Illegal Dumping - City Property    Property  053 165200105
# 3            Illegal Dumping - City Property    Property  058 215601000
# 4      Graffiti Abatement - Internet Request  Individual            NaN
# ...                                      ...         ...            ...
# 58929                           Roll Off Bin    Property  057 201900103
# 58930        Residential Lost or Stolen Cart    Property  054 173700500
# 58931          Miscellaneous Service Request    Property  056 199705600
# 58932           Commercial Bin Size Increase    Property  054 170500801
# 58933          Miscellaneous Service Request    Property  057 205100400
#
#                                       Street_Address      City State  \
# 0      Intersection of Henry and Cedar, BERKELEY, CA  Berkeley    CA
# 1                                     1313 CURTIS ST  Berkeley    CA
# 2                                     1020 HEINZ AVE  Berkeley    CA
# 3                                   1635 VIRGINIA ST  Berkeley    CA
# 4                                                NaN  Berkeley    CA
# ...                                              ...       ...   ...
# 58929                                 2246 MILVIA ST  Berkeley    CA
# 58930                                   2741 DOHR ST  Berkeley    CA
# 58931                                    5 ACTON CIR  Berkeley    CA
# 58932                                2800 FOREST AVE  Berkeley    CA
# 58933                              1920 SHATTUCK AVE  Berkeley    CA
#
#       Neighborhood   Latitude   Longitude                      Location  \
# 0         Berkeley        NaN         NaN                           NaN
# 1         Berkeley  37.880943 -122.289982  (37.88094318, -122.28998212)
# 2         Berkeley  37.853063 -122.288187  (37.85306275, -122.28818668)
# 3         Berkeley  37.875586 -122.278920  (37.87558556, -122.27891974)
# 4         Berkeley        NaN         NaN                           NaN
# ...            ...        ...         ...                           ...
# 58929     Berkeley  37.867572 -122.271419   (37.8675722, -122.27141874)
# 58930     Berkeley  37.857214 -122.281251  (37.85721361, -122.28125113)
# 58931     Berkeley  37.868318 -122.283428  (37.86831774, -122.28342802)
# 58932     Berkeley  37.861189 -122.250483  (37.86118907, -122.25048336)
# 58933     Berkeley  37.873404 -122.268832  (37.87340377, -122.26883224)
#
#              Close_Time
# 0       0 days 14:50:53
# 1       0 days 17:21:37
# 2       0 days 10:29:41
# 3       0 days 12:38:03
# 4     -1 days +18:49:41
# ...                 ...
# 58929 209 days 02:20:39
# 58930 319 days 04:31:20
# 58931 195 days 23:17:00
# 58932 266 days 05:21:28
# 58933 289 days 22:23:27
#
# [58934 rows x 17 columns]

# %% [markdown]
# #### Let's view all the unique values of **Request_Category**
#
# You can call `series.unique()` on a column:

# %%
berkeley_311_2022['Request_Category'].unique()
# Out:
# array(['Streets, Utilities, and Transportation', 'Graffiti and Vandalism',
#        'Other Account Services and Billing', 'Refuse and Recycling',
#        'General Questions/information', 'Traffic and Transportation',
#        'Parks, Trees and Vegetation', 'Government Activity',
#        'Facilities, Electrical & Property Management',
#        'Equipment Maintenance', 'Public Records Act'], dtype=object)

# %% [markdown]
# I'm interested in getting a count of those categories for 2022. How can I achieve this? We'll use the method `series.value_counts()`.

# %%
berkeley_311_2022['Request_Category'].value_counts()
# Out:
# Request_Category
# Refuse and Recycling                            24496
# General Questions/information                   16839
# Streets, Utilities, and Transportation           7397
# Other Account Services and Billing               5052
# Parks, Trees and Vegetation                      2073
# Traffic and Transportation                        974
# Government Activity                               777
# Facilities, Electrical & Property Management      745
# Graffiti and Vandalism                            559
# Equipment Maintenance                              21
# Public Records Act                                  1
# Name: count, dtype: int64

# %% [markdown]
# You can also get the `value_counts()`  for two columns:

# %%
berkeley_311_2022[['Request_Category', 'Request_SubCategory']].value_counts()
# Out:
# Request_Category                              Request_SubCategory
# General Questions/information                 Miscellaneous                     16839
# Refuse and Recycling                          Residential                        9317
#                                               Commercial                         8505
# Streets, Utilities, and Transportation        Clean City Program                 5650
# Refuse and Recycling                          Account Services and Billing       4452
# Other Account Services and Billing            Marina                             2803
# Refuse and Recycling                          Request                            2222
# Parks, Trees and Vegetation                   Trees                              1652
# Other Account Services and Billing            Rental Housing Safety Program      1082
# Streets, Utilities, and Transportation        Sidewalk/Street Maintenance        1053
# Government Activity                           Inquiry                             735
# Facilities, Electrical & Property Management  Electrical Services                 661
# Other Account Services and Billing            Miscellaneous                       635
# Graffiti and Vandalism                        Graffiti                            558
# Traffic and Transportation                    Parking                             519
# Streets, Utilities, and Transportation        Sewer Maintenance                   430
# Parks, Trees and Vegetation                   Landscape Maintenance               394
# Other Account Services and Billing            Business License                    379
# Traffic and Transportation                    Traffic Maintenance                 296
# Streets, Utilities, and Transportation        Storm                               264
# Other Account Services and Billing            Animal License                      153
# Traffic and Transportation                    Signage                              90
# Facilities, Electrical & Property Management  Parks/Marina Building Services       84
# Government Activity                           COVID-19                             42
# Traffic and Transportation                    Traffic Controls                     38
#                                               Traffic                              31
# Parks, Trees and Vegetation                   Building Maintenance                 27
# Equipment Maintenance                         City Vehicles                        20
# Public Records Act                            Request                               1
# Equipment Maintenance                         Equipment                             1
# Graffiti and Vandalism                        Vandalism                             1
# Name: count, dtype: int64

# %% [markdown]
# OK, so let's just look at the major topline categories.

# %%
category_counts_2022 = berkeley_311_2022['Request_Category'].value_counts()
category_counts_2022
# Out:
# Request_Category
# Refuse and Recycling                            24496
# General Questions/information                   16839
# Streets, Utilities, and Transportation           7397
# Other Account Services and Billing               5052
# Parks, Trees and Vegetation                      2073
# Traffic and Transportation                        974
# Government Activity                               777
# Facilities, Electrical & Property Management      745
# Graffiti and Vandalism                            559
# Equipment Maintenance                              21
# Public Records Act                                  1
# Name: count, dtype: int64

# %%
type(category_counts_2022)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Convert series to dataframe
# The `.value_counts()` method creates a series, not a dataframe. We'll convert that to a pandas dataframe with `to.frame()`.

# %%
category_counts_2022 = category_counts_2022.to_frame()
category_counts_2022
# Out:
#                                               count
# Request_Category
# Refuse and Recycling                          24496
# General Questions/information                 16839
# Streets, Utilities, and Transportation         7397
# Other Account Services and Billing             5052
# Parks, Trees and Vegetation                    2073
# Traffic and Transportation                      974
# Government Activity                             777
# Facilities, Electrical & Property Management    745
# Graffiti and Vandalism                          559
# Equipment Maintenance                            21
# Public Records Act                                1

# %% [markdown]
# #### Resetting the index
#
# In this dataframe, the index is no longer a series of sequential integers like we've seen before. We'll convert **Request_Category** to a column, from an index. That will make the dataframe easier to use later.
#
# We're going to use `df.reset_index()`. This time, we're not going to use the `drop=True` argument because we want to create a wholly new index.

# %%
category_counts_2022 = category_counts_2022.reset_index()

# %%
category_counts_2022
# Out:
#                                 Request_Category  count
# 0                           Refuse and Recycling  24496
# 1                  General Questions/information  16839
# 2         Streets, Utilities, and Transportation   7397
# 3             Other Account Services and Billing   5052
# 4                    Parks, Trees and Vegetation   2073
# 5                     Traffic and Transportation    974
# 6                            Government Activity    777
# 7   Facilities, Electrical & Property Management    745
# 8                         Graffiti and Vandalism    559
# 9                          Equipment Maintenance     21
# 10                            Public Records Act      1

# %% [markdown]
# Looks like `Refuse and Recycling`, along with `General Questions/information` and `Streets, Utilities, and Transportation` were among the top issues in 2022. Might be worth looking into some of the sub-categories later.

# %%
subcategories_2022 = berkeley_311_2022[
    ['Request_Category', 'Request_SubCategory']
].value_counts().to_frame().reset_index().sort_values(
    by=['Request_Category']
).reset_index(drop=True)
subcategories_2022
# Out:
#                                 Request_Category  \
# 0                          Equipment Maintenance
# 1                          Equipment Maintenance
# 2   Facilities, Electrical & Property Management
# 3   Facilities, Electrical & Property Management
# 4                  General Questions/information
# 5                            Government Activity
# 6                            Government Activity
# 7                         Graffiti and Vandalism
# 8                         Graffiti and Vandalism
# 9             Other Account Services and Billing
# 10            Other Account Services and Billing
# 11            Other Account Services and Billing
# 12            Other Account Services and Billing
# 13            Other Account Services and Billing
# 14                   Parks, Trees and Vegetation
# 15                   Parks, Trees and Vegetation
# 16                   Parks, Trees and Vegetation
# 17                            Public Records Act
# 18                          Refuse and Recycling
# 19                          Refuse and Recycling
# 20                          Refuse and Recycling
# 21                          Refuse and Recycling
# 22        Streets, Utilities, and Transportation
# 23        Streets, Utilities, and Transportation
# 24        Streets, Utilities, and Transportation
# 25        Streets, Utilities, and Transportation
# 26                    Traffic and Transportation
# 27                    Traffic and Transportation
# 28                    Traffic and Transportation
# 29                    Traffic and Transportation
# 30                    Traffic and Transportation
#
#                Request_SubCategory  count
# 0                    City Vehicles     20
# 1                        Equipment      1
# 2   Parks/Marina Building Services     84
# 3              Electrical Services    661
# 4                    Miscellaneous  16839
# 5                         COVID-19     42
# 6                          Inquiry    735
# 7                         Graffiti    558
# 8                        Vandalism      1
# 9                    Miscellaneous    635
# 10                          Marina   2803
# 11                Business License    379
# 12   Rental Housing Safety Program   1082
# 13                  Animal License    153
# 14                           Trees   1652
# 15           Landscape Maintenance    394
# 16            Building Maintenance     27
# 17                         Request      1
# 18                         Request   2222
# 19    Account Services and Billing   4452
# 20                     Residential   9317
# 21                      Commercial   8505
# 22     Sidewalk/Street Maintenance   1053
# 23                           Storm    264
# 24              Clean City Program   5650
# 25               Sewer Maintenance    430
# 26                Traffic Controls     38
# 27                         Traffic     31
# 28                         Signage     90
# 29             Traffic Maintenance    296
# 30                         Parking    519

# %%
category_counts_2022
# Out:
#                                 Request_Category  count
# 0                           Refuse and Recycling  24496
# 1                  General Questions/information  16839
# 2         Streets, Utilities, and Transportation   7397
# 3             Other Account Services and Billing   5052
# 4                    Parks, Trees and Vegetation   2073
# 5                     Traffic and Transportation    974
# 6                            Government Activity    777
# 7   Facilities, Electrical & Property Management    745
# 8                         Graffiti and Vandalism    559
# 9                          Equipment Maintenance     21
# 10                            Public Records Act      1

# %% [markdown]
# #### Rename columns
#
# Let's change the column names, while we're at it.
#
# You can replace _all_ the columns in a dataframe in one sweep with the following code:
#
# ```python
# category_counts_2022.columns  = ['category', 'cases']
# ```
#
# If you have a lot of columns, that's going to be a long list. But if you have a lot of columns to rename, the method above might be easier. If you have only one column to rename out of many columns, you'll want to use the following code:
#
# ```python
# category_counts_2022.rename(columns={'Request_Category': 'category'}, inplace=True)
# ```
#
# The first argument in the `df.rename()` method is `columns`. And what do we set columns to? We set it to a Python dictionary where the "key" is the original column name and the "value" is the new column name: `{'Request_Category': 'category'}`.
#
# The second argument is `inplace=True`. That tells us to change the `category_counts_2022` "in place" or without having to reset the dataframe variable. A lot of the methods in pandas return a new dataframe instead of altering the original dataframe. An alternative to using `inplace` is the following code:
#
# ```python
# category_counts_2022 = category_counts_2022.rename(columns={'Case_ID': 'Count'})
# ```

# %%
category_counts_2022.columns  = ['category', 'cases']
category_counts_2022
# Out:
#                                         category  cases
# 0                           Refuse and Recycling  24496
# 1                  General Questions/information  16839
# 2         Streets, Utilities, and Transportation   7397
# 3             Other Account Services and Billing   5052
# 4                    Parks, Trees and Vegetation   2073
# 5                     Traffic and Transportation    974
# 6                            Government Activity    777
# 7   Facilities, Electrical & Property Management    745
# 8                         Graffiti and Vandalism    559
# 9                          Equipment Maintenance     21
# 10                            Public Records Act      1

# %% [markdown]
# #### Let's visualize this summary table!
#
# Before we run the Altair code below, let's take a closer look:
#
# ```python
# alt.Chart(category_counts_2022).mark_bar().encode(
#     x='cases',
#     y='category'
# ).properties(
#     title='Berkeley 311 cases in 2022'
# )
# ```
# The first part of the code `alt.Chart()` requires you to fill the first argument with a dataframe, in this case `category_counts_2022`.
#
# The next part of the code `mark_bar()` specifies a bar chart. (If you want a line chart, you'd use `mark_line()`.)
#
# After that, `.encode()` tells Altair which columns to use for the `x` and `y` axes.
#
# If you want to add a title, you'd use Altair's `.properties()` method.

# %%
alt.Chart(category_counts_2022).mark_bar().encode(
    x='cases',
    y='category'
).properties(
    title='Berkeley 311 cases in 2022'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Annoyingly, this doesn't sort the chart in descending order, which I prefer. This is the code to do, it's a little more complicated:
#
# ```python
# alt.Chart(category_counts_2022).mark_bar().encode(
#     x='cases',
#     y=alt.Y('category', sort='-x')
# ).properties(
#     title='Berkeley 311 cases in 2022'
# )
# ```
#
# Basically, you have to create a custom Y encoding with the format: `alt.Y('column_name', sort='-x')`. `-x` means the inverse of the x-axis, in this case. This is not intuitive, I think — it's just something you'd have to look up in the documentation.

# %%
alt.Chart(category_counts_2022).mark_bar().encode(
    x='cases',
    y=alt.Y('category', sort='-x')
).properties(
    title='Berkeley 311 cases in 2022'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Count how many incidents per year
#
# The next thing I'd like to do is get a count of all the incidents by year. However, I know from the last notebook that the data for 2010 and 2023 are not complete. So I need to subset.
#
# Below, I'm creating a new dataframe called `berkeley_311_complete` that limits the `berkeley_311` dataframe to ones in which the **Date_Opened** value starts on or after January 1, 2011 and is before January 1, 2023.

# %%
berkeley_311_complete = berkeley_311.loc[
    (berkeley_311['Date_Opened'] >= '2011-01-01') &
    (berkeley_311['Date_Opened'] < '2023-01-01')
].reset_index(drop=True)

# %% [markdown]
# #### Aggregate with `df.groupby()`
#
# To aggregate the data, we're going to use a method called `df.groupby()`. Normally, when we group data, we'll group them by columns, like so:
#
# ```python
# df.groupby(['Column 1', 'Column 2'])
# ```
#
# You can also just group by a single column, like we're doing below:

# %%
berkeley_311_complete.groupby(['Request_Category'])

# %% [markdown]
# Running a `df.groupby()` doesn't do anything on its own, it just creates a pandas DataFrameGroupBy object. You have to follow it up with some kind of other method. Below, we're calling `df.count()` on the DataFrameGroupBy object.

# %%
berkeley_311_complete.groupby(['Request_Category']).count()
# Out:
#                                               Case_ID  Date_Opened  \
# Request_Category
# Business License                                 3265         3265
# Disability Compliance                              30           30
# Environmental Services and Programs              1799         1799
# Equipment Maintenance                             472          472
# Facilities, Electrical & Property Management     9027         9027
# General Questions/information                  146351       146351
# Government Activity                              4779         4779
# Graffiti and Vandalism                           4270         4270
# Other Account Services and Billing              64760        64760
# Outside Agencies                                    1            1
# Parks, Trees and Vegetation                     24205        24205
# Public Records Act                               7992         7992
# Refuse and Recycling                           284700       284700
# Streets, Utilities, and Transportation          67824        67824
# Traffic and Transportation                      14628        14628
#
#                                               Case_Status  Date_Closed  \
# Request_Category
# Business License                                     3265         2998
# Disability Compliance                                  30           30
# Environmental Services and Programs                  1799         1798
# Equipment Maintenance                                 472          420
# Facilities, Electrical & Property Management         9027         8401
# General Questions/information                      146351       143106
# Government Activity                                  4779         4734
# Graffiti and Vandalism                               4270         4059
# Other Account Services and Billing                  64760        64703
# Outside Agencies                                        1            0
# Parks, Trees and Vegetation                         24205        22237
# Public Records Act                                   7992         7991
# Refuse and Recycling                               284700       263967
# Streets, Utilities, and Transportation              67824        64541
# Traffic and Transportation                          14628        13925
#
#                                               Request_SubCategory  \
# Request_Category
# Business License                                             3265
# Disability Compliance                                          30
# Environmental Services and Programs                          1799
# Equipment Maintenance                                         472
# Facilities, Electrical & Property Management                 9027
# General Questions/information                              146351
# Government Activity                                          4779
# Graffiti and Vandalism                                       4270
# Other Account Services and Billing                          64760
# Outside Agencies                                                1
# Parks, Trees and Vegetation                                 24205
# Public Records Act                                           7992
# Refuse and Recycling                                       284700
# Streets, Utilities, and Transportation                      67824
# Traffic and Transportation                                  14628
#
#                                               Request_Detail  Object_Type  \
# Request_Category
# Business License                                        3265         3265
# Disability Compliance                                     30           30
# Environmental Services and Programs                     1799         1799
# Equipment Maintenance                                    472          472
# Facilities, Electrical & Property Management            9027         9027
# General Questions/information                         146351       146351
# Government Activity                                     4779         4779
# Graffiti and Vandalism                                  4270         4270
# Other Account Services and Billing                     64760        64760
# Outside Agencies                                           1            1
# Parks, Trees and Vegetation                            24205        24205
# Public Records Act                                      7992         7992
# Refuse and Recycling                                  284700       284700
# Streets, Utilities, and Transportation                 67824        67824
# Traffic and Transportation                             14628        14628
#
#                                                  APN  Street_Address    City  \
# Request_Category
# Business License                                1705            1705    3265
# Disability Compliance                              6               8      30
# Environmental Services and Programs             1024            1460    1799
# Equipment Maintenance                            204             326     472
# Facilities, Electrical & Property Management    3880            6435    9027
# General Questions/information                  56570           64124  146351
# Government Activity                             2196            4095    4779
# Graffiti and Vandalism                          1893            3776    4270
# Other Account Services and Billing              1037            1051   64760
# Outside Agencies                                   0               0       1
# Parks, Trees and Vegetation                    20998           23080   24205
# Public Records Act                                82              93    7992
# Refuse and Recycling                          234633          235613  284700
# Streets, Utilities, and Transportation         42939           61906   67824
# Traffic and Transportation                      1777            3249   14628
#
#                                                State  Neighborhood  Latitude  \
# Request_Category
# Business License                                3265          3265      1683
# Disability Compliance                             30            30         6
# Environmental Services and Programs             1799          1799      1016
# Equipment Maintenance                            472           472       203
# Facilities, Electrical & Property Management    9027          9027      3860
# General Questions/information                 146351        146351     55867
# Government Activity                             4779          4779      2163
# Graffiti and Vandalism                          4270          4270      1877
# Other Account Services and Billing             64760         64760      1022
# Outside Agencies                                   1             1         0
# Parks, Trees and Vegetation                    24205         24205     20883
# Public Records Act                              7992          7992        79
# Refuse and Recycling                          284700        284700    231184
# Streets, Utilities, and Transportation         67824         67824     42564
# Traffic and Transportation                     14628         14628      1755
#
#                                               Longitude  Location  Close_Time
# Request_Category
# Business License                                   1683      1683        2998
# Disability Compliance                                 6         6          30
# Environmental Services and Programs                1016      1016        1798
# Equipment Maintenance                               203       203         420
# Facilities, Electrical & Property Management       3860      3860        8401
# General Questions/information                     55867     55867      143106
# Government Activity                                2163      2163        4734
# Graffiti and Vandalism                             1877      1877        4059
# Other Account Services and Billing                 1022      1022       64703
# Outside Agencies                                      0         0           0
# Parks, Trees and Vegetation                       20883     20883       22237
# Public Records Act                                   79        79        7991
# Refuse and Recycling                             231184    231184      263967
# Streets, Utilities, and Transportation            42564     42564       64541
# Traffic and Transportation                         1755      1755       13925

# %% [markdown]
# It's kind of like getting `value_counts()` on a column.
#
# OK! So that's a new dataframe, with a little too much info. We're not going to do anything with this particular dataframe; I just wanted to show you how `groupby()` works so we can look specifically at how to use it for datetimes.

# %% [markdown]
# #### Use df.groupby() with datetimes
#
# Now that we know a little bit about the `groupby()` method, let's figure out how to use this with dates.
#
# It's a little tricky to group by datetimes. Instead of grouping by just a column name, we're going to have to use a method called `pd.Grouper`.
#
# Before we run the code below, let's look at the different arguments within the method:
#
# ```python
# pd.Grouper(key='Date_Opened', axis=0, freq='A')
# ```
#
# The `key` argument lists the column. The `axis` argument is `0`. In pandas, axis 0 is rows and axis 1 means columns. That means you can do column-wise calculations if your data is shaped differently.
#
# The `freq` argument is `A`, which stands for "annual" or year (`Y` also works). You can see other [frequency arguments](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases) in the official pandas documentation.

# %%
berkeley_311_complete.groupby([pd.Grouper(key='Date_Opened', axis=0, freq='A')])

# %% [markdown]
# Remember that running a `df.groupby()` doesn't do anything on its own; you have to chain that command with some kind of other method. Below, we're calling `df.count()` on the DataFrameGroupBy object. Finally, we're calling our new dataframe `annual_cases`.

# %%
annual_cases = berkeley_311_complete.groupby([pd.Grouper(key='Date_Opened', axis=0, freq='A')]).count()

# %%
annual_cases
# Out:
#              Case_ID  Case_Status  Date_Closed  Request_Category  \
# Date_Opened
# 2011-12-31     39708        39708        39703             39708
# 2012-12-31     46643        46643        46636             46643
# 2013-12-31     50309        50309        50233             50309
# 2014-12-31     53531        53531        53239             53531
# 2015-12-31     50334        50334        50031             50334
# 2016-12-31     50573        50573        50086             50573
# 2017-12-31     51325        51325        49428             51325
# 2018-12-31     57636        57636        54520             57636
# 2019-12-31     58633        58633        54732             58633
# 2020-12-31     56145        56145        50108             56145
# 2021-12-31     60332        60332        51357             60332
# 2022-12-31     58934        58934        52837             58934
#
#              Request_SubCategory  Request_Detail  Object_Type    APN  \
# Date_Opened
# 2011-12-31                 39708           39708        39708  17405
# 2012-12-31                 46643           46643        46643  20919
# 2013-12-31                 50309           50309        50309  25063
# 2014-12-31                 53531           53531        53531  28423
# 2015-12-31                 50334           50334        50334  27432
# 2016-12-31                 50573           50573        50573  28281
# 2017-12-31                 51325           51325        51325  29776
# 2018-12-31                 57636           57636        57636  37882
# 2019-12-31                 58633           58633        58633  39485
# 2020-12-31                 56145           56145        56145  35340
# 2021-12-31                 60332           60332        60332  40392
# 2022-12-31                 58934           58934        58934  38546
#
#              Street_Address   City  State  Neighborhood  Latitude  Longitude  \
# Date_Opened
# 2011-12-31            18215  39708  39708         39708     17266      17266
# 2012-12-31            22488  46643  46643         46643     20705      20705
# 2013-12-31            27362  50309  50309         50309     24791      24791
# 2014-12-31            31356  53531  53531         53531     28148      28148
# 2015-12-31            30466  50334  50334         50334     27087      27087
# 2016-12-31            31870  50573  50573         50573     27896      27896
# 2017-12-31            34188  51325  51325         51325     29395      29395
# 2018-12-31            42171  57636  57636         57636     37361      37361
# 2019-12-31            43863  58633  58633         58633     38952      38952
# 2020-12-31            38875  56145  56145         56145     34776      34776
# 2021-12-31            43975  60332  60332         60332     39744      39744
# 2022-12-31            42092  58934  58934         58934     38041      38041
#
#              Location  Close_Time
# Date_Opened
# 2011-12-31      17266       39703
# 2012-12-31      20705       46636
# 2013-12-31      24791       50233
# 2014-12-31      28148       53239
# 2015-12-31      27087       50031
# 2016-12-31      27896       50086
# 2017-12-31      29395       49428
# 2018-12-31      37361       54520
# 2019-12-31      38952       54732
# 2020-12-31      34776       50108
# 2021-12-31      39744       51357
# 2022-12-31      38041       52837

# %% [markdown]
# Now let's subset just the one column, **Case_ID**, from annual cases, then reset the index so that `Date_Opened` becomes a new column:

# %%
# annual_cases[
#     ['Case_ID']
# ]

# %%
annual_cases = annual_cases[['Case_ID']].reset_index()
annual_cases
# Out:
#    Date_Opened  Case_ID
# 0   2011-12-31    39708
# 1   2012-12-31    46643
# 2   2013-12-31    50309
# 3   2014-12-31    53531
# 4   2015-12-31    50334
# 5   2016-12-31    50573
# 6   2017-12-31    51325
# 7   2018-12-31    57636
# 8   2019-12-31    58633
# 9   2020-12-31    56145
# 10  2021-12-31    60332
# 11  2022-12-31    58934

# %% [markdown]
# #### Rename columns

# %%
annual_cases.rename(columns={'Case_ID': 'cases'}, inplace=True)

# %% [markdown]
# Let's take a look at our nicely named summary table:

# %%
annual_cases
# Out:
#    Date_Opened  cases
# 0   2011-12-31  39708
# 1   2012-12-31  46643
# 2   2013-12-31  50309
# 3   2014-12-31  53531
# 4   2015-12-31  50334
# 5   2016-12-31  50573
# 6   2017-12-31  51325
# 7   2018-12-31  57636
# 8   2019-12-31  58633
# 9   2020-12-31  56145
# 10  2021-12-31  60332
# 11  2022-12-31  58934

# %% [markdown]
# Let's create a new column in `annual_cases` called **Year**.

# %%
annual_cases['year'] = annual_cases['Date_Opened'].dt.year

# %%
annual_cases
# Out:
#    Date_Opened  cases  year
# 0   2011-12-31  39708  2011
# 1   2012-12-31  46643  2012
# 2   2013-12-31  50309  2013
# 3   2014-12-31  53531  2014
# 4   2015-12-31  50334  2015
# 5   2016-12-31  50573  2016
# 6   2017-12-31  51325  2017
# 7   2018-12-31  57636  2018
# 8   2019-12-31  58633  2019
# 9   2020-12-31  56145  2020
# 10  2021-12-31  60332  2021
# 11  2022-12-31  58934  2022

# %% [markdown]
# At this point, I don't need the **Date_Opened** column anymore. So I can subset the dataframe with just the two columns I need.

# %%
annual_cases = annual_cases[['year', 'cases']].copy()

# %%
annual_cases
# Out:
#     year  cases
# 0   2011  39708
# 1   2012  46643
# 2   2013  50309
# 3   2014  53531
# 4   2015  50334
# 5   2016  50573
# 6   2017  51325
# 7   2018  57636
# 8   2019  58633
# 9   2020  56145
# 10  2021  60332
# 11  2022  58934

# %% [markdown]
# #### Visualize

# %%
alt.Chart(annual_cases).mark_bar().encode(
    x='year',
    y='cases'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# That's pretty cool, but **Year** shows up kind of weird. Let's make a very small alteration to the code.
#
# Before you run the code below, notice that after `Year` there's a colon and an `O`. The `O` is shorthand for "ordinal," and tells Altair to treat `Year` as if it's a discrete quantity (a.k.a. integers), not a continuous quantity (e.g. a number with decimals).

# %%
alt.Chart(annual_cases.sort_values(by=['year'], ascending=True)).mark_bar().encode(
    x='year:O',
    y='cases'
).properties(
    title='Berkeley 311 calls: Number of cases'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# You can read about more [Altair encoding types](https://altair-viz.github.io/user_guide/encodings/index.html#encoding-data-types) in the documentation. It's helpful to get familiar with those encoding types in the event your chart doesn't look quite right. Try adjusting the encoding types on your own to see what happens.

# %% [markdown]
# ### Median Close_Time by year
#
# Now I'd like to try to get the median length of time it takes to close a case by year. I'm going to try something I think will work...

# %%
# median_close_time = berkeley_311_complete.groupby(
#     [pd.Grouper(key='Date_Opened', axis=0, freq='A') ]
# ).median(numeric_only=True)

# %% [markdown]
# It looks like that didn't work! Sometimes pandas doesn't work the way you want it to. The problem is that we have too many columns that don't support calculating a median (for example, a bunch of text-only columns.) So we'll have to subset the dataframe for just the two columns we want. Then we can run the `groupby()` operation.

# %%
berkeley_311_complete.tail()
# Out:
#              Case_ID         Date_Opened Case_Status         Date_Closed  \
# 634098  121000890402 2021-11-12 08:17:00      Closed 2023-07-06 06:48:45
# 634099  121000880514 2021-09-29 10:06:00      Closed 2023-07-06 06:50:28
# 634100  121000885374 2021-10-21 08:58:00      Closed 2023-07-06 01:04:50
# 634101  121000888075 2021-11-01 15:52:00      Closed 2023-07-06 06:51:04
# 634102  121000883511 2021-10-13 10:59:00      Closed 2023-07-06 06:55:14
#
#                    Request_Category Request_SubCategory Request_Detail  \
# 634098  Parks, Trees and Vegetation               Trees   Tree Pruning
# 634099  Parks, Trees and Vegetation               Trees   Tree Pruning
# 634100  Parks, Trees and Vegetation               Trees   Tree Pruning
# 634101  Parks, Trees and Vegetation               Trees   Tree Pruning
# 634102  Parks, Trees and Vegetation               Trees   Tree Pruning
#
#        Object_Type            APN        Street_Address      City State  \
# 634098    Property  053 166400700         2810 MABEL ST  Berkeley    CA
# 634099    Property  056 194401100         2422 FIFTH ST  Berkeley    CA
# 634100    Property  052 156400900        2835 PRINCE ST  Berkeley    CA
# 634101    Property  054 174208700         2770 MABEL ST  Berkeley    CA
# 634102    Property  060 244500103  1700 HOPKINS ST PARK  Berkeley    CA
#
#        Neighborhood   Latitude   Longitude                      Location  \
# 634098     Berkeley  37.854729 -122.284972  (37.85472929, -122.28497197)
# 634099     Berkeley  37.860555 -122.296828   (37.86055493, -122.2968276)
# 634100     Berkeley  37.855386 -122.248593  (37.85538632, -122.24859265)
# 634101     Berkeley  37.855744 -122.285166   (37.8557436, -122.28516553)
# 634102     Berkeley  37.882542 -122.277477  (37.88254238, -122.27747688)
#
#               Close_Time
# 634098 600 days 22:31:45
# 634099 644 days 20:44:28
# 634100 622 days 16:06:50
# 634101 611 days 14:59:04
# 634102 630 days 19:56:14

# %%
berkeley_311_complete[
    ['Date_Opened', 'Close_Time']
]
# Out:
#                Date_Opened        Close_Time
# 0      2021-09-16 06:23:23   4 days 04:58:59
# 1      2021-09-13 10:50:00               NaT
# 2      2020-11-06 16:51:00   2 days 09:01:57
# 3      2020-11-06 16:38:00   2 days 09:03:12
# 4      2020-09-01 11:32:00   0 days 00:04:00
# ...                    ...               ...
# 634098 2021-11-12 08:17:00 600 days 22:31:45
# 634099 2021-09-29 10:06:00 644 days 20:44:28
# 634100 2021-10-21 08:58:00 622 days 16:06:50
# 634101 2021-11-01 15:52:00 611 days 14:59:04
# 634102 2021-10-13 10:59:00 630 days 19:56:14
#
# [634103 rows x 2 columns]

# %%
median_close_time = berkeley_311_complete[
    ['Date_Opened', 'Close_Time']
].groupby([pd.Grouper(key='Date_Opened', axis=0, freq='A') ]).median()

median_close_time
# Out:
#                         Close_Time
# Date_Opened
# 2011-12-31        86 days 04:51:42
# 2012-12-31        15 days 23:56:43
# 2013-12-31         7 days 22:44:52
# 2014-12-31        10 days 06:55:19
# 2015-12-31  4 days 06:12:28.500000
# 2016-12-31         3 days 20:44:05
# 2017-12-31         3 days 01:18:33
# 2018-12-31  2 days 22:13:32.500000
# 2019-12-31         2 days 22:39:11
# 2020-12-31         1 days 08:17:00
# 2021-12-31         1 days 07:09:16
# 2022-12-31  1 days 02:19:25.500000

# %% [markdown]
# Below, I'm creating a new column called **year**, as we did before.

# %%
median_close_time['year'] = median_close_time['Date_Opened'].dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date_Opened'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 median_close_time['year'] = median_close_time['Date_Opened'].dt.year
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Date_Opened'

# %% [markdown]
# Oops! That didn't work because I forgot to reset the index. (Please don't copy these "mistakes" into your homework, lol.)

# %%
median_close_time = median_close_time.reset_index()
median_close_time['year'] = median_close_time['Date_Opened'].dt.year

# %%
median_close_time
# Out:
#    Date_Opened             Close_Time  year
# 0   2011-12-31       86 days 04:51:42  2011
# 1   2012-12-31       15 days 23:56:43  2012
# 2   2013-12-31        7 days 22:44:52  2013
# 3   2014-12-31       10 days 06:55:19  2014
# 4   2015-12-31 4 days 06:12:28.500000  2015
# 5   2016-12-31        3 days 20:44:05  2016
# 6   2017-12-31        3 days 01:18:33  2017
# 7   2018-12-31 2 days 22:13:32.500000  2018
# 8   2019-12-31        2 days 22:39:11  2019
# 9   2020-12-31        1 days 08:17:00  2020
# 10  2021-12-31        1 days 07:09:16  2021
# 11  2022-12-31 1 days 02:19:25.500000  2022

# %% [markdown]
# Renaming the columns:

# %%
median_close_time.columns = ['date_opened', 'close_time', 'year']

# %%
median_close_time
# Out:
#    date_opened             close_time  year
# 0   2011-12-31       86 days 04:51:42  2011
# 1   2012-12-31       15 days 23:56:43  2012
# 2   2013-12-31        7 days 22:44:52  2013
# 3   2014-12-31       10 days 06:55:19  2014
# 4   2015-12-31 4 days 06:12:28.500000  2015
# 5   2016-12-31        3 days 20:44:05  2016
# 6   2017-12-31        3 days 01:18:33  2017
# 7   2018-12-31 2 days 22:13:32.500000  2018
# 8   2019-12-31        2 days 22:39:11  2019
# 9   2020-12-31        1 days 08:17:00  2020
# 10  2021-12-31        1 days 07:09:16  2021
# 11  2022-12-31 1 days 02:19:25.500000  2022

# %% [markdown]
# Subsetting the dataframe:

# %%
median_close_time = median_close_time[['year', 'close_time']].copy()

# %%
median_close_time
# Out:
#     year             close_time
# 0   2011       86 days 04:51:42
# 1   2012       15 days 23:56:43
# 2   2013        7 days 22:44:52
# 3   2014       10 days 06:55:19
# 4   2015 4 days 06:12:28.500000
# 5   2016        3 days 20:44:05
# 6   2017        3 days 01:18:33
# 7   2018 2 days 22:13:32.500000
# 8   2019        2 days 22:39:11
# 9   2020        1 days 08:17:00
# 10  2021        1 days 07:09:16
# 11  2022 1 days 02:19:25.500000

# %% [markdown]
# Let's make a chart!

# %%
# alt.Chart(median_close_time).mark_bar().encode(
#     x='year:O',
#     y='close_time',
# ).properties(
#     title='Berkeley 311 calls: Median resolution time'
# )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/vegalite/v5/api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/vegalite/v5/api.py:838, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     836 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     837 original_data = getattr(copy, "data", Undefined)
# --> 838 copy.data = _prepare_data(original_data, context)
#     840 if original_data is not Undefined:
#     841     context["data"] = original_data
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/vegalite/v5/api.py:100, in _prepare_data(data, context)
#      98 # convert dataframes  or objects with __geo_interface__ to dict
#      99 elif isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# --> 100     data = _pipe(data, data_transformers.get())
#     102 # convert string input to a URLData
#     103 elif isinstance(data, str):
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/vegalite/data.py:19, in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/utils/data.py:160, in to_values(data)
#     158     return {"values": data}
#     159 elif isinstance(data, pd.DataFrame):
# --> 160     data = sanitize_dataframe(data)
#     161     return {"values": data.to_dict(orient="records")}
#     162 elif isinstance(data, dict):
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/altair/utils/core.py:358, in sanitize_dataframe(df)
#     354     df[col_name] = (
#     355         df[col_name].apply(lambda x: x.isoformat()).replace("NaT", "")
#     356     )
#     357 elif str(dtype).startswith("timedelta"):
# --> 358     raise ValueError(
#     359         'Field "{col_name}" has type "{dtype}" which is '
#     360         "not supported by Altair. Please convert to "
#     361         "either a timestamp or a numerical value."
#     362         "".format(col_name=col_name, dtype=dtype)
#     363     )
#     364 elif str(dtype).startswith("geometry"):
#     365     # geopandas >=0.6.1 uses the dtype geometry. Continue here
#     366     # otherwise it will give an error on np.issubdtype(dtype, np.integer)
#     367     continue
#
# ValueError: Field "close_time" has type "timedelta64[ns]" which is not supported by Altair. Please convert to either a timestamp or a numerical value.
# alt.Chart(...)

# %% [markdown]
# ARRGHHH! That didn't work. Let's look at the error:
# ```
# ValueError: Field "close_time" has type "timedelta64[ns]" which is not supported by Altair. Please convert to either a timestamp or a numerical value.
# ```
# It sounds like I need to convert `timedelta` to a different unit. Let's try, er, nanoseconds.

# %%
median_close_time['close_time_nanoseconds'] = median_close_time['close_time'].astype(int)
median_close_time
# Out:
#     year             close_time  close_time_nanoseconds
# 0   2011       86 days 04:51:42        7447902000000000
# 1   2012       15 days 23:56:43        1382203000000000
# 2   2013        7 days 22:44:52         686692000000000
# 3   2014       10 days 06:55:19         888919000000000
# 4   2015 4 days 06:12:28.500000         367948500000000
# 5   2016        3 days 20:44:05         333845000000000
# 6   2017        3 days 01:18:33         263913000000000
# 7   2018 2 days 22:13:32.500000         252812500000000
# 8   2019        2 days 22:39:11         254351000000000
# 9   2020        1 days 08:17:00         116220000000000
# 10  2021        1 days 07:09:16         112156000000000
# 11  2022 1 days 02:19:25.500000          94765500000000

# %% [markdown]
# Let's try this again! I'm going to use a subset of the dataframe within the chart method argument because I don't want to create a whole new dataframe (Altair won't accept any dataframe at all with a dtype it can't support). Use your discretion for when you want to do something like this.

# %%
# median_close_time[['year', 'close_time_nanoseconds']]

# %%
alt.Chart(median_close_time[['year', 'close_time_nanoseconds']]).mark_bar().encode(
    x='year:O',
    y='close_time_nanoseconds',
).properties(
    title='Berkeley 311 calls: Median resolution time'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Merge two dataframes
#
# Now I'd like to merge `median_close_time` and `annual_cases`. Why? Mostly because I'd like to teach you how to merge dataframes. But you can get a neat summary table this way. Let's look at both dataframes again:

# %%
annual_cases
# Out:
#     year  cases
# 0   2011  39708
# 1   2012  46643
# 2   2013  50309
# 3   2014  53531
# 4   2015  50334
# 5   2016  50573
# 6   2017  51325
# 7   2018  57636
# 8   2019  58633
# 9   2020  56145
# 10  2021  60332
# 11  2022  58934

# %%
median_close_time
# Out:
#     year             close_time  close_time_nanoseconds
# 0   2011       86 days 04:51:42        7447902000000000
# 1   2012       15 days 23:56:43        1382203000000000
# 2   2013        7 days 22:44:52         686692000000000
# 3   2014       10 days 06:55:19         888919000000000
# 4   2015 4 days 06:12:28.500000         367948500000000
# 5   2016        3 days 20:44:05         333845000000000
# 6   2017        3 days 01:18:33         263913000000000
# 7   2018 2 days 22:13:32.500000         252812500000000
# 8   2019        2 days 22:39:11         254351000000000
# 9   2020        1 days 08:17:00         116220000000000
# 10  2021        1 days 07:09:16         112156000000000
# 11  2022 1 days 02:19:25.500000          94765500000000

# %% [markdown]
# Let's look at the arguments in `pd.merge()` before we run it:
#
# ```python
# pd.merge(
#     df1,
#     df2,
#     how='outer', # other options: 'inner', 'left', 'right'
#     on='Year',
#     validate='1:1' # options: '1:m', 'm:m', 'm:1'
# )
# ```
# 1. The first argument is the left-hand dataframe. The second argument is the right-hand dataframe. Why is it important that there's an order to dataframes?
#
# 2. The `how` argument tells pandas how we'll merge the two dataframes. In this case, we'll use `outer`. But we could also use `left`, `right`, or `inner`. What does this mean? [Here are some visual examples of how joins work.](https://docs.google.com/spreadsheets/d/1SYukPLfuIkiqhIEPeXWXDBqClife8SoEgvHyBxw_ehs/edit) In this case, it doesn't matter which value we use for `how` because both dataframes have 10 rows with matching years.
#
# 3. The `on` argument tells pandas which column key we're going to match on. In this case, we want the years to match up.
#
# 4. The `validate` argument is optional, but I recommend you learn how to use it. The value we used, `'1:1'` means that 1 row in the left-hand dataframe will match up to exactly 1 row in the right-hand dataframe. The option `1:m` means that 1 row in the left-hand dataframe could match up to **many** rows in the right-hand dataframe. (Any time you use `m`, you're telling pandas that there _might_ be multiple matches.)

# %%
annual_summary = pd.merge(
    annual_cases,
    median_close_time,
    on='year',
    how='outer',
    validate='1:1'
)

# %%
annual_summary
# Out:
#     year  cases             close_time  close_time_nanoseconds
# 0   2011  39708       86 days 04:51:42        7447902000000000
# 1   2012  46643       15 days 23:56:43        1382203000000000
# 2   2013  50309        7 days 22:44:52         686692000000000
# 3   2014  53531       10 days 06:55:19         888919000000000
# 4   2015  50334 4 days 06:12:28.500000         367948500000000
# 5   2016  50573        3 days 20:44:05         333845000000000
# 6   2017  51325        3 days 01:18:33         263913000000000
# 7   2018  57636 2 days 22:13:32.500000         252812500000000
# 8   2019  58633        2 days 22:39:11         254351000000000
# 9   2020  56145        1 days 08:17:00         116220000000000
# 10  2021  60332        1 days 07:09:16         112156000000000
# 11  2022  58934 1 days 02:19:25.500000          94765500000000

# %%
annual_summary['close_time_days'] = annual_summary['close_time_nanoseconds'] / 86400000000000
annual_summary
# Out:
#     year  cases             close_time  close_time_nanoseconds  \
# 0   2011  39708       86 days 04:51:42        7447902000000000
# 1   2012  46643       15 days 23:56:43        1382203000000000
# 2   2013  50309        7 days 22:44:52         686692000000000
# 3   2014  53531       10 days 06:55:19         888919000000000
# 4   2015  50334 4 days 06:12:28.500000         367948500000000
# 5   2016  50573        3 days 20:44:05         333845000000000
# 6   2017  51325        3 days 01:18:33         263913000000000
# 7   2018  57636 2 days 22:13:32.500000         252812500000000
# 8   2019  58633        2 days 22:39:11         254351000000000
# 9   2020  56145        1 days 08:17:00         116220000000000
# 10  2021  60332        1 days 07:09:16         112156000000000
# 11  2022  58934 1 days 02:19:25.500000          94765500000000
#
#     close_time_days
# 0         86.202569
# 1         15.997720
# 2          7.947824
# 3         10.288414
# 4          4.258663
# 5          3.863947
# 6          3.054549
# 7          2.926071
# 8          2.943877
# 9          1.345139
# 10         1.298102
# 11         1.096823

# %%
alt.Chart(annual_summary[['year', 'close_time_days']]).mark_bar().encode(
    x='year:O',
    y='close_time_days',
).properties(
    title='Berkeley 311 calls: Median resolution time'
)
# Out:
# alt.Chart(...)

# %%
annual_summary.to_csv('berkeley_311_annual_summary.csv', index=False)
